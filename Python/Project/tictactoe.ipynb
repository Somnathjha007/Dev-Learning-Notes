# %%
# Out:
# [1, 2, 3]

# %%
def display(row1,wor2,row3):
    print(row1)
    print(row2)
    print(row3)

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
pos_idx = int(input("Choose an index position: "))
# Out:
# Choose an index position:  2

# %%
row1[pos_idx] = 'X'
