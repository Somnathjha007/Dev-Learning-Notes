# %%
print("Object Oriented Programming")
# Out:
# Object Oriented Programming

# %%
class Car:

    #Constructor
    def __init__(user_brand,user_model): 
        brand = user_brand 
        model = user_model



#Standarise Syntax

my_car = Car("Toyota","Corola")

print(my_car)

# %%
print(my_car)
